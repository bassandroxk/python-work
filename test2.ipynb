# %% [markdown]
# # test 04.22.26

# %%
#class variable and instance variable
class student:
    school_name="upes"
    def _init_(self,name,age):
        self.name=name
        self.age=age
    s1=student("john","20")
    s2=student("doe","22")
print(s1.name)
print(s1.age)
print(s1.school_name)
print(s2.name)
print(s2.age)
print(s2.school_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 #class variable and instance variable
# ----> 2 class student:
#       3     school_name="upes"
#       4     def _init_(self,name,age):
#
# Cell In[42], line 7, in student()
#       5     self.name=name
#       6     self.age=age
# ----> 7 s1=student("john","20")
#       8 s2=student("doe","22")
#
# TypeError: student() takes no arguments

# %%
class employee:
    company ="abc ltd"
    def _init_(self,name,salary):
        self.name=name
        self.salary=salary
# showdetails()
def showdetails(self):
            print("name","salary")
            employee=employee("hello",10000)
            employee2=employee("hi",20000)
print(employee.company)
print(employee.company)

class company_change:
    def _init_(self,name):
        self.name=name
        print("company name:", self.name)
        company_changex=("cdf?")
# Out:
# abc ltd
# abc ltd

# %%
class mathhelper:
    @staticmethod
    def iseven(num):
        if num%2==0:
            print("true")
        else:
            print("false")
print(mathhelper.iseven(4))
print(mathhelper.iseven(5))
# Out:
# true
# None
# false
# None

# %%
#3section b

# %%
class bankaccount:
    name="sbi"
    def _init_(self,name,balance):
        self.name=name
        self.balance=balance
    def deposit(amount):
        if amount<0:
            print("invalid amount")
        else:
            self.balance+=amount
        print("amount deposited:", amount)

    def withdraw(amount):
        if amount<0:
            print("invalid")
        else:
            self.balance-=amount
        print("amount withdrawn:", amount)

# %%
class student:
        def _name_(self,name):
            self.name=name
            print("student name:", self.name)
        def _doc_(self,doc):
            self.doc=doc
            print("student doc:", self.doc)
        def module(self,module):
            self.module=module
            print("student module:", self.module)


        pass

print("Student Information:", student._name_("john"), student._doc_("12345"), student.module("python"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 15
#      10             print("student module:", self.module)
#      13         pass
# ---> 15 print("Student Information:", student._name_("john"), student._doc_("12345"), student.module("python"))
#
# TypeError: student._name_() missing 1 required positional argument: 'name'

# %%
class product:
    def __init__(self,name,price):
        self.name=name
        self.price=price
    def __str__(self):
        return f"product name: {self.name}, price: {self.price}"
    def __add__(self,other):
        if isinstance(other,product):
            return self.price+other.price
        return NotImplemented
    def __eq__(self,other):
        if isinstance(other,product):
            return self.price==other.price
        return NotImplemented
p1=product("laptop",1000)
p2=product("phone",500)
p3=product("tablet",1000)
print(p1)
print(p1+p2)
print(p1==p2)
# Out:
# product name: laptop, price: 1000
# 1500
# False
