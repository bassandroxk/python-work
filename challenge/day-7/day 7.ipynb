# %% [markdown]
# #### 1.Take a string and print first, last character and length of string.

# %%
s = input("Enter a string: " )
print("first character:", s[0])
print("last character:", s[-1])
print("length of string:", len(s))

# %% [markdown]
# #### 3. Write a function to find factorial.

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact
n = int(input("Enter a number: "))
print("Factorial =", factorial(n))

# %% [markdown]
# #### Q4. Print all keys and values separately.

# %%
d = {"A": 10, "B": 20, "C": 30}

print("Keys:", d.keys())
print("Values:", d.values())
# Out:
# Keys: dict_keys(['A', 'B', 'C'])
# Values: dict_values([10, 20, 30])

# %% [markdown]
# #### 5 Check whether a number is an Armstrong number.

# %%
n = int(input("Enter a number: "))
temp = n
s = 0
while temp > 0:
    digit = temp % 10
    s += digit ** 3
    temp //= 10
if s == n:
    print(f"{n} is an Armstrong number.")
else:
    print(f"{n} is not an Armstrong number.")
