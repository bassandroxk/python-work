# %% [markdown]
# #### 1. Add a new key-value pair to dictionary.

# %%
d = {"A": 10, "B": 20}
d["C"] = 30
print(d)

# %% [markdown]
# #### Q2. Find symmetric difference between two sets.

# %%
A = {1, 2, 3}
B = {3, 4, 5}

print(A ^ B)
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# #### Q4) Write a program to find if given number is prime number or not.

# %%
n=int(input("enter a no: "))
divi=0
for i in range(1,n+1):
    if(n%i==0):
        divi+=1
if divi==2:
    print(f"{n} is a prime no")
else:
    print("not a prime no")

# %% [markdown]
#  #### 4. Check whether a given number is multiple of five or not.

# %%
a=int(input("Enter a no:"))
if a%5==0:
    print("this no is multiple of 5")
else:
    print("this no is not multiple of 5")

# %% [markdown]
# #### Q5. Remove duplicates using set.

# %%
unique=list(set(List))
print("Unique elements:", unique)
# Out:
# Unique elements: [1, 2, 3, 4, 5]

# %% [markdown]
# #### Q6. Find intersection of two lists without using set.

# %%
list1 = [1, 2, 3, 4, 5]
list2 = [4, 5, 6, 7, 8]
intersection = [x for x in list1 if x in list2]
print("Intersection:", intersection)
# Out:
# Intersection: [4, 5]

# %% [markdown]
# #### 5 Print all keys and values separately from a dictionary.

# %%
d = {"A": 10, "B": 20, "C": 30}
print("Keys:", list(d.keys()))
print("Values:", list(d.values()))

# %% [markdown]
# #### Q8. Predict output:</h4>

# %%
for i in range(5):
    if i % 2 == 0:
        continue
    print(i)

# %% [markdown]
# #### Q9. Find common elements between two lists.

# %%
common=[]

for x in unique:
    if x in l2:
        common.append(x)
print("Common elements:", common)
# Out:
# Common elements: [5]

# %% [markdown]
# #### Q10. Find average of elements in tuple.

# %%
t = (10, 20, 30, 40)

avg = sum(t) / len(t)

print("Average = %d" %avg)
# Out:
# Average = 25

# %% [markdown]
# #### 11. Print multiplication table using function.

# %%
def printtable(n):
    for i in range(1, 11):
        print(f"{n} x {i} = {n * i}")

n=int(input("Enter a number: "))
printtable(n)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# #### Q12. Take a sentence and print longest word.

# %%
s=input("Enter a sentence: ")
words = s.split()
longest = max(words, key=len)
print("Longest word:", longest)
# Out:
# Longest word: auIBIUCbaSIUNciajsNCoiuAB

# %% [markdown]
# #### Q13. Reverse each word in a sentence.

# %%
s = input("Enter sentence: ")

words = s.split()

for w in words:
    print(w[::-1], end=" ")
# Out:
# uhbiv

# %% [markdown]
# #### Q8) Convert all lower cases to upper case in a string.

# %%
n=input("enter a string: ")
n.upper()

# %% [markdown]
# #### 15. Find maximum and minimum element.

# %%
lst = [10, 20, 30, 40]
print("maximum =", max(lst))
print("minimum =", min(lst))
