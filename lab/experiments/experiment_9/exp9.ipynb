# %% [markdown]
# --------------------------------------------------------------
# EXPERIMENT- 9
# --------------------------------------------------------------

# %%
class students:
    def __init__(self, name, id, phy, chem, math):
        self.name = name
        self.id = id
        self.phy = phy
        self.chem = chem
        self.math = math
    students_list = []
    def set_marks(self, phy, chem, math):
        self.phy = phy
        self.chem = chem
        self.math = math
    def display_info(self):
        print(f'Name: {self.name}, ID: {self.id}, Physics: {self.phy}, Chemistry: {self.chem}, Math: {self.math}')
student1 = students('gsg', 20413, 85, 90, 95)
student2 = students('hdgg', 22414, 92, 88, 95)
student3 = students('fheh', 19415, 78, 85, 82)
student4 = students('ghdh', 21416, 90, 92, 88)
student5 = students('dghdh', 23417, 88, 85, 90)
student1.display_info()
student2.display_info()
student3.display_info()
student4.display_info()
student5.display_info()
# Out:
# Name: gsg, ID: 20413, Physics: 85, Chemistry: 90, Math: 95
# Name: hdgg, ID: 22414, Physics: 92, Chemistry: 88, Math: 95
# Name: fheh, ID: 19415, Physics: 78, Chemistry: 85, Math: 82
# Name: ghdh, ID: 21416, Physics: 90, Chemistry: 92, Math: 88
# Name: dghdh, ID: 23417, Physics: 88, Chemistry: 85, Math: 90

# %%
# add constructor to initialize student information
class StudentRecord:
    def __init__(self, name, sap_id, marks):
        self.name = name
        self.sap_id = sap_id
        self.marks = marks

    def display(self):
        print(f"Name: {self.name} | SAP ID: {self.sap_id} | Marks: {self.marks}")

    def marks_percentage(self):
        return sum(self.marks.values()) / len(self.marks)

    def result(self):
        return "Pass" if all(mark > 40 for mark in self.marks.values()) else "Fail"


def class_average(records):
    return sum(record.marks_percentage() for record in records) / len(records)


input_data = [
    ("ghdh", "52525223", {"phy": 24, "chem": 32, "maths": 41}),
    ("fqefqe", "624524525", {"phy": 25, "chem": 22, "maths": 25}),
    ("gqqr", "525252525", {"phy": 74, "chem": 92, "maths": 64}),
]

records = [StudentRecord(name, sap_id, marks) for name, sap_id, marks in input_data]

for record in records:
    record.display()
    print("Percentage:", f"{record.marks_percentage():.2f}%")
    print("Result:", record.result())
    print("-" * 70)

print("Class average percentage:", f"{class_average(records):.2f}%")
# Out:
# Name: ghdh | SAP ID: 52525223 | Marks: {'phy': 24, 'chem': 32, 'maths': 41}
# Percentage: 32.33%
# Result: Fail
# ----------------------------------------------------------------------
# Name: fqefqe | SAP ID: 624524525 | Marks: {'phy': 25, 'chem': 22, 'maths': 25}
# Percentage: 24.00%
# Result: Fail
# ----------------------------------------------------------------------
# Name: gqqr | SAP ID: 525252525 | Marks: {'phy': 74, 'chem': 92, 'maths': 64}
# Percentage: 76.67%
# Result: Pass
# ----------------------------------------------------------------------
# Class average percentage: 44.33%

# %%
# create program to implement different type of inheritence
class animal:
    def kind(self):
        print("I am an animal.")
class insect(animal):
    def type(self):
        print("I am an insect.")
class butterfly(insect):
    def name(self):
        print("I am a butterfly.")
class bee(insect):
    def name(self):
        print("I am a bee.")
class bird(animal):
    def type(self):
        print("I am a bird.")
class sparrow(bird):
    def name(self):
        print("I am a sparrow.")

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from sketchpy import canvas
#       2 obj = canvas.sketch_from_image('butterfly.jpg')
#       3 obj.draw()
#
# ModuleNotFoundError: No module named 'sketchpy'
